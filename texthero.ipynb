# %% [markdown]
# <a href="https://colab.research.google.com/github/aydinmyilmaz/python_packages/blob/main/texthero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/jbesomi/texthero

# %%
# !pip install -qqq texthero
# Out:
#      |████████████████████████████████| 1.5 MB 5.1 MB/s
#      |████████████████████████████████| 235 kB 11.2 MB/s
#      |████████████████████████████████| 749 kB 42.5 MB/s

# %%
import texthero as hero
import pandas as pd

df = pd.read_csv(
   "https://github.com/jbesomi/texthero/raw/master/dataset/bbcsport.csv"
)

df.sample(10)
# Out:
#                                                   text      topic
# 506  Bell set for England debut\n\nBath prop Duncan...      rugby
# 484  Arsenal 1-1 Sheff Utd\n\nAndy Gray's 90th-minu...   football
# 40   Gatlin and Hayes win Owen awards\n\nAmerican O...  athletics
# 214  World XI triumph in tsunami match\n\nTsunami A...    cricket
# 523  Munster Cup tie switched to Spain\n\nMunster's...      rugby
# 657  Serena becomes world number two\n\nSerena Will...     tennis
# 446  Greece defy the odds at Euro 2004\n\nGreece ar...   football
# 592  Campbell to be Lions consultant\n\nFormer gove...      rugby
# 451  Blatter suggests offside change\n\nFifa presid...   football
# 116  Batsman Van Jaarsveld joins Kent\n\nSouth Afri...    cricket

# %%
df['pca'] = (
   df['text']
   .pipe(hero.clean)
   .pipe(hero.tfidf)
   .pipe(hero.pca)
)

# %%
df.sample(5)
# Out:
#                                                   text      topic  \
# 383  Old Firm pair handed suspensions\n\nCeltic's H...   football
# 366  Liverpool revel in night of glory\n\nLiverpool...   football
# 169  BSkyB lands England deal\n\nLive coverage of E...    cricket
# 310  Brentford v Southampton\n\nGriffin Park\n\nTue...   football
# 52   Gebrselassie in London triple bid\n\nDouble Ol...  athletics
#
#                                               pca
# 383  [-0.044624180047955715, 0.00190306591535966]
# 366  [-0.10572406111340701, -0.15917739451897783]
# 169   [0.13084626033873142, 0.028605876605544166]
# 310   [-0.0731048417458716, -0.10448575004090839]
# 52      [-0.0962790643963514, 0.1129354410607307]

# %%
hero.scatterplot(df, 'pca', color='topic', title="PCA BBC Sport news")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
